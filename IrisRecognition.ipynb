# %%
import IrisLocalization
import IrisNormalization
import ImageEnhancement
import FeatureExtraction
import IrisMatching
import PerformanceEvaluation
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.neighbors import NearestCentroid
from sklearn.metrics.pairwise import cosine_similarity
import os
import cv2
import scipy.signal

def main():
    train_features = []
    train_labels = []
    test_features = []
    test_labels = []

    for i in range(1, 109):
        folder_name = f"{i:03}"
        folder_path = os.path.join(main_folder_path, folder_name)
        folder_1_path = os.path.join(folder_path, "1")
        folder_2_path = os.path.join(folder_path, "2")

    # Load training data
        if os.path.exists(folder_1_path):
            for j in range(1, 4):
                img_file = f"{folder_name}_1_{j}.bmp"
                img_path = os.path.join(folder_1_path, img_file)
                image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if image is not None:
                   localized_iris = IrisLocalization.localize_iris(image)
                   inner_circle, outer_circle = localized_iris
                   normalized_iris = IrisNormalization.normalize_iris(image, inner_circle, outer_circle)                      
                   enhanced_iris = ImageEnhancement.enhance_iris(normalized_iris)
                   feature_vector = FeatureExtraction.get_feature_vector(enhanced_iris)
                   train_features.append(feature_vector)
                   train_labels.append(i)
     # Load testing data
        if os.path.exists(folder_2_path):
            for j in range(1, 5):
                img_file = f"{folder_name}_2_{j}.bmp"
                img_path = os.path.join(folder_2_path, img_file)
                image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if image is not None:
                   localized_iris = IrisLocalization.localize_iris(image)
                   inner_circle, outer_circle = localized_iris
                   normalized_iris = IrisNormalization.normalize_iris(image, inner_circle, outer_circle)                  
                   enhanced_iris = ImageEnhancement.enhance_iris(normalized_iris)
                   feature_vector = FeatureExtraction.get_feature_vector(enhanced_iris)
                   test_features.append(feature_vector)
                   test_labels.append(i)
                    
    train_features = np.array(train_features)
    train_labels = np.array(train_labels)
    test_features = np.array(test_features)
    test_labels = np.array(test_labels)

    predicted_labels = iris_matching(train_features, train_labels, test_features)
    match_scores =   
    crr,roc_auc = performance_evaluation(true_labels, predicted_labels, match_scores)
    print(f"Correct Recognition Rate (CRR): {crr:.2f}")
    print(f"Area Under the ROC Curve (AUC): {roc_auc:.2f}")
    
if __name__ == "__main__":
    main()
